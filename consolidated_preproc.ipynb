# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Lectura de datos

# %%
data = pd.read_csv('./consolidated_dataset/tweets.csv', lineterminator='\n')
data_btc = pd.read_csv('./consolidated_dataset/btc_history.csv')

# %% [markdown]
# # Preprocesamiento de datos

# %%
data_btc = data_btc.loc[data_btc.index.repeat(1000)].reset_index(drop=True)
data['price_change'] = data_btc.price_change

# %%
data.date = pd.to_datetime(data.date, format='%Y-%m-%d').dt.date

# %%
from datetime import timedelta

current_day = data.date.min()
current_price_change = data.price_change[0]
a = [current_day]
df = []

for t in data.itertuples():
    if t[1] == current_day:
        a.append(t[2])
    else:
        a.append(current_price_change)
        df.append(a)
        current_day += timedelta(days=1)
        current_price_change = t[3]
        a = [current_day]
        a.append(t[2])

a.append(current_price_change)
df.append(a)

# %%
data = pd.DataFrame(df)

# %%
columns = ['date']

for i in range(1, len(data.columns) - 1):
    columns.append('s_{}'.format(i))

columns.append('price_change')

data.columns = columns
data.drop(columns=['date'], inplace=True)
data
# Out:
#         s_1     s_2     s_3     s_4     s_5     s_6     s_7     s_8     s_9  \
# 0    0.0000  0.0000  0.0000  0.2023 -0.5204 -0.2732  0.0000  0.0000  0.0000
# 1    0.0000  0.4588  0.3612  0.0000  0.0000  0.5423  0.0000 -0.1027  0.0258
# 2    0.8528  0.2500 -0.3802 -0.1027  0.0000  0.0000  0.0000 -0.6249  0.0000
# 3    0.8832  0.3869  0.0000  0.4588  0.0000  0.0000  0.0000  0.0000  0.0000
# 4    0.0000 -0.5719  0.0000 -0.0772  0.5719  0.0000  0.2960 -0.2263  0.6369
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 193  0.0000  0.0000 -0.4588  0.0000  0.8777  0.0000  0.9358  0.5106  0.0000
# 194  0.3595  0.0000  0.0000 -0.5859  0.4588  0.0000  0.0000  0.4404 -0.6476
# 195  0.4215  0.2263  0.4753  0.4310  0.7450  0.0000  0.0000  0.2732 -0.3182
# 196  0.0000  0.0000  0.0000  0.3612  0.0000  0.0000  0.1779  0.4215  0.2023
# 197  0.0000  0.0000  0.0000  0.5484  0.4184  0.0000  0.0000  0.8176  0.0000
#
#        s_10  ...   s_992   s_993   s_994   s_995   s_996   s_997   s_998  \
# 0   -0.1759  ...  0.8807  0.4588  0.0000  0.0000  0.7964 -0.7579  0.8313
# 1    0.4926  ...  0.0000  0.4404  0.4926  0.0000  0.0000  0.0000  0.4926
# 2    0.0000  ...  0.2960  0.0000  0.0000  0.2732  0.5893  0.0000  0.0000
# 3    0.5106  ...  0.0000  0.8910 -0.5859  0.4635  0.0000  0.0000  0.8172
# 4    0.8750  ... -0.2500  0.0000  0.2714  0.0000  0.8858  0.4019  0.0000
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 193  0.5423  ...  0.0000  0.0000  0.6249  0.0000  0.4588  0.0000  0.0000
# 194  0.5719  ...  0.0000  0.0000  0.3612  0.2924  0.0000 -0.2732 -0.0516
# 195  0.2960  ...  0.0000  0.0000  0.0000  0.0000  0.6705  0.8553  0.3595
# 196 -0.6124  ... -0.1406  0.0000  0.0000 -0.4019  0.0000 -0.0772  0.0000
# 197  0.2263  ...  0.3595  0.5562  0.0000  0.5423 -0.2732  0.8159 -0.6476
#
#      s_999  s_1000  price_change
# 0    0.000  0.7184           1.0
# 1    0.000  0.8625           1.0
# 2    0.000 -0.6705           1.0
# 3    0.000  0.0000          -1.0
# 4    0.000  0.5562           1.0
# ..     ...     ...           ...
# 193  0.000  0.0000          -1.0
# 194  0.765  0.4019          -1.0
# 195  0.000  0.0000          -1.0
# 196  0.000  0.0000          -1.0
# 197  0.000  0.4939          -1.0
#
# [198 rows x 1001 columns]

# %%
data.to_csv('./consolidated_dataset/consolidated.csv', index=False)
