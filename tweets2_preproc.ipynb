# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('tweets.csv', sep=';', on_bad_lines='skip',
                   lineterminator='\n', low_memory=False)
data
# Out:
#                     id             user              fullname  url  \
# 0         1.132977e+18     KamdemAbdiel         Abdiel kamdem  NaN
# 1         1.132977e+18        bitcointe             Bitcointe  NaN
# 2         1.132977e+18        3eyedbran   Bran - 3 Eyed Raven  NaN
# 3         1.132977e+18    DetroitCrypto           J. Scardina  NaN
# 4         1.132977e+18     mmursaleen72    Muhammad Mursaleen  NaN
# ...                ...              ...                   ...  ...
# 16889760  1.198262e+18    JacobCanfield        Jacob Canfield  NaN
# 16889761  1.198266e+18          Vizique               Vizique  NaN
# 16889762  1.198266e+18         torusJKL  Gal Buki ($torusJKL)  NaN
# 16889763  1.198266e+18  Adekunl95628158       Adekunle Daniel  NaN
# 16889764  1.198266e+18       HaraldoXRP                 Harry  NaN
#
#                        timestamp  replies  likes  retweets  \
# 0         2019-05-27 11:49:14+00        0      0         0
# ...

# %%
data = data[['timestamp', 'text\r']]
data.rename(columns={'timestamp': 'date', 'text\r': 'text'}, inplace=True)
data
# Out:
#                             date  \
# 0         2019-05-27 11:49:14+00
# 1         2019-05-27 11:49:18+00
# 2         2019-05-27 11:49:06+00
# 3         2019-05-27 11:49:22+00
# 4         2019-05-27 11:49:23+00
# ...                          ...
# 16889760  2019-11-23 15:28:50+00
# 16889761  2019-11-23 15:45:55+00
# 16889762  2019-11-23 15:45:56+00
# 16889763  2019-11-23 15:45:57+00
# 16889764  2019-11-23 15:45:06+00
#
#                                                        text
# 0         È appena uscito un nuovo video! LES CRYPTOMONN...
# 1         Cardano: Digitize Currencies; EOS https://t.co...
# 2         Another Test tweet that wasn't caught in the s...
# 3         Current Crypto Prices! \n\nBTC: $8721.99 USD\n...
# 4         Spiv (Nosar Baz): BITCOIN Is An Asset &amp; NO...
# ...                                                     ...
# 16889760  Happy #FibonacciDay \n\nA while back I created...
# 16889761  Bitcoin Suisse Certificates :) https://t.co/nd...
# ...

# %%
data.isna().sum()
# Out:
# date    0
# text    0
# dtype: int64

# %%
from datetime import datetime


data.date = np.array([datetime.strptime(d.split('+')[0],
                                        '%Y-%m-%d %H:%M:%S')
                      for d in data.date])

# %%
def check_skipped_days():
    x = 0
    arr = np.array([])
    day_before = datetime.now()
    index_before = 0

    for index, d in enumerate(data.date):
        diff = 0

        if x == 0:
            day_before, index_before = d, index
            x+=1
            continue

        diff = (d - day_before).days

        if diff > 1:
            arr = np.append(arr, '{} => {} : {} days'.format(index_before, index, diff))

        day_before, index_before = d, index

    return arr

# %%
skipped_days = check_skipped_days()

print(skipped_days)
len(skipped_days)
# Out:
# ['12 => 13 : 4 days' '15 => 16 : 16 days' '21 => 22 : 3763 days' ...
#  '16889683 => 16889684 : 10 days' '16889704 => 16889705 : 2 days'
#  '16889753 => 16889754 : 5 days']
# 144982

# %%
print(data.date.min())
print(data.date.max())
print((data.date.max() - data.date.min()).days)
# Out:
# 2007-04-19 07:14:38
# 2019-11-23 15:45:57
# 4601
